# %% [markdown]
# ## Cài đặt các thư viện cần thiết, clone git

# %%
import sklearn
# !pip install --upgrade scikit-learn
# !pip install timm
# !pip install thop
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 20.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.7 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/Talented-Q/POSTER_V2.git
# Out:
# Cloning into 'POSTER_V2'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 76 (delta 25), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (76/76), 3.11 MiB | 6.33 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %% [markdown]
# ## Tạo thư mục chứa dataset, giải nén file dataset

# %%
# !cd /content/POSTER_V2
# !mkdir /content/POSTER_V2/data

# %%
cd /content/POSTER_V2/data
# Out:
# /content/POSTER_V2/data

# %%
#rafdb
# !unrar x /content/drive/MyDrive/POSTER_V2/raf-db.rar
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
#fer2013
# !unrar x /content/drive/MyDrive/POSTER_V2/images_folders.rar

# %% [markdown]
# ## Tải backbone ir50 và mobilefacenet từ drive (cần có id)

# %%
cd /content/POSTER_V2/models/pretrain
# Out:
# /content/POSTER_V2/models/pretrain

# %%
! gdown --id 1h-sWdJM0-7KOZZ72oJpFrVi7Pn4iE5r3
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1h-sWdJM0-7KOZZ72oJpFrVi7Pn4iE5r3
# To: /content/POSTER_V2/models/pretrain/ir50.pth
# 100% 122M/122M [00:01<00:00, 89.1MB/s]

# %%
! gdown --id 104xCJNzxOUKuoH51Shxj7uxpvMR-uP-S
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=104xCJNzxOUKuoH51Shxj7uxpvMR-uP-S
# To: /content/POSTER_V2/models/pretrain/mobilefacenet_model_best.pth.tar
# 100% 12.3M/12.3M [00:00<00:00, 34.5MB/s]

# %%
cd /content/POSTER_V2
# Out:
# /content/POSTER_V2

# %% [markdown]
# ## CosFace

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize

import psutil
import humanize
import os
import GPUtil as GPU

GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
    process = psutil.Process(os.getpid())
    print("Gen RAM Free: " + humanize.naturalsize(psutil.virtual_memory().available), " |     Proc size: " + humanize.naturalsize(process.memory_info().rss))
    print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total     {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()

# %%
# !pip install --upgrade gupload

from pydrive.auth import GoogleAuth
from google.colab import auth

# Authenticate and create the PyDrive client.
auth.authenticate_user()

# %%
# !gupload --to '1rWXyi4Mg-4r33fXOpqMPveOj5s4qqmCb'

# %% [markdown]
# ### Huấn luyện với hàm lỗi CosFace

# %%
# !python main.py --data /content/POSTER_V2/data/raf-db --data_type RAF-DB --lr 3.5e-5 --batch-size 32 --epochs 30 --gpu 0.9 --checkpoint_path /content/drive/MyDrive/POSTER_V2/checkpoint_cosface --best_checkpoint_path /content/drive/MyDrive/POSTER_V2/checkpoint_cosface --head "cosface"
# Out:
# Training time: 07-22 09:42
# init CosFace with
# self.m 0.4
# self.s 64.0
# load_weight 304
# Current learning rate:  3.5e-05
# Epoch: [0][  0/384]	Loss 48.1161 (37.7240)	Accuracy  0.000 ( 0.000)
# Epoch: [0][ 30/384]	Loss 25.1523 (30.3448)	Accuracy  9.375 ( 0.454)
# Epoch: [0][ 60/384]	Loss 18.5548 (26.0723)	Accuracy 31.250 (10.707)
# Epoch: [0][ 90/384]	Loss 25.9884 (24.3740)	Accuracy 18.750 (14.646)
# Epoch: [0][120/384]	Loss 18.6071 (23.3746)	Accuracy 25.000 (16.955)
# Epoch: [0][150/384]	Loss 18.8824 (22.5377)	Accuracy 37.500 (19.143)
# Epoch: [0][180/384]	Loss 23.9477 (21.9235)	Accuracy 18.750 (20.718)
# Epoch: [0][210/384]	Loss 17.6971 (21.4762)	Accuracy 34.375 (21.638)
# Epoch: [0][240/384]	Loss 19.6805 (21.0434)	Accuracy 15.625 (22.433)
# Epoch: [0][270/384]	Loss 17.1119 (20.5745)	Accuracy 25.000 (23.605)
# Epoch: [0][300/384]	Loss 21.2351 (20.0788)	Accuracy 28.125 (24.704)
# Epoch: [0][330/384]	Loss 18.7076 (19.7314)	Accuracy 34.375 (25.533)
# ...

# %%
# !python main.py --data /content/POSTER_V2/data/raf-db --data_type RAF-DB --lr 3.5e-5 --batch-size 32 --epochs 30 --gpu 0.9
# Out:
# Training time: 07-22 09:51
# init CosFace with
# self.m 0.4
# self.s 64.0
# load_weight 304
# Current learning rate:  3.5e-05
# Epoch: [0][  0/384]	Loss 50.2529 (39.2809)	Accuracy  0.000 ( 0.000)
# Epoch: [0][ 30/384]	Loss 27.6991 (29.5746)	Accuracy  9.375 ( 3.125)
# Epoch: [0][ 60/384]	Loss 23.7785 (25.6083)	Accuracy 21.875 (12.910)
# Epoch: [0][ 90/384]	Loss 22.3559 (24.0703)	Accuracy 21.875 (16.827)
# Epoch: [0][120/384]	Loss 22.3063 (23.1628)	Accuracy 18.750 (18.853)
# Epoch: [0][150/384]	Loss 22.1938 (22.3742)	Accuracy 21.875 (20.613)
# Epoch: [0][180/384]	Loss 18.5675 (21.7587)	Accuracy 34.375 (22.039)
# Epoch: [0][210/384]	Loss 20.4192 (21.4653)	Accuracy 25.000 (22.556)
# Epoch: [0][240/384]	Loss 20.9695 (20.9877)	Accuracy 21.875 (23.716)
# Epoch: [0][270/384]	Loss 17.0751 (20.5420)	Accuracy 21.875 (24.741)
# Epoch: [0][300/384]	Loss 16.5050 (20.1785)	Accuracy 40.625 (25.483)
# Epoch: [0][330/384]	Loss 16.5359 (19.7603)	Accuracy 31.250 (26.647)
# ...

# %% [markdown]
# ## ArcFace

# %%
# !python main.py --data /content/POSTER_V2/data/raf-db --data_type RAF-DB --lr 3.5e-5 --batch-size 32 --epochs 30 --gpu 0.9 --head "arcface"
# Out:
# Training time: 07-23 09:58
# init ArcFace with
# self.m 0.4
# self.s 64.0
# load_weight 304
# Current learning rate:  3.5e-05
# Epoch: [0][  0/384]	Loss 43.9220 (36.5851)	Accuracy  0.000 ( 0.000)
# Epoch: [0][ 30/384]	Loss 25.6333 (29.5538)	Accuracy  0.000 ( 0.000)
# Epoch: [0][ 60/384]	Loss 22.5851 (24.9468)	Accuracy 25.000 (11.117)
# Epoch: [0][ 90/384]	Loss 24.6796 (22.9613)	Accuracy 18.750 (16.106)
# Epoch: [0][120/384]	Loss 16.1682 (22.0045)	Accuracy 37.500 (18.259)
# Epoch: [0][150/384]	Loss 17.7143 (21.2930)	Accuracy  9.375 (19.309)
# Epoch: [0][180/384]	Loss 11.6259 (20.5799)	Accuracy 46.875 (20.571)
# Epoch: [0][210/384]	Loss 15.6639 (20.0008)	Accuracy 28.125 (21.749)
# Epoch: [0][240/384]	Loss 16.2820 (19.4647)	Accuracy 37.500 (22.484)
# Epoch: [0][270/384]	Loss 16.1402 (19.0184)	Accuracy 34.375 (23.299)
# Epoch: [0][300/384]	Loss 15.8484 (18.6319)	Accuracy 25.000 (23.718)
# Epoch: [0][330/384]	Loss 17.7823 (18.2533)	Accuracy 21.875 (24.443)
# ...

# %% [markdown]
# ## SupCon Lost

# %%
# !python main_supcon_loss.py --data /content/POSTER_V2/data/raf-db --data_type RAF-DB --lr 3.5e-5 --batch-size 32 --epochs 30 --gpu 0.9
# Out:
# Training time: 07-23 17:10
# load_weight 304
# Current learning rate:  3.5e-05
# torch.Size([32, 2, 7])
# torch.Size([32])
# Traceback (most recent call last):
#   File "/content/POSTER_V2/main_supcon_loss.py", line 530, in <module>
#     main()
#   File "/content/POSTER_V2/main_supcon_loss.py", line 167, in main
#     train_acc, train_los = train(train_loader, model, criterion, optimizer, epoch, args)
#   File "/content/POSTER_V2/main_supcon_loss.py", line 231, in train
#     acc1, _ = accuracy(output, target, topk=(1, 5))
#   File "/content/POSTER_V2/main_supcon_loss.py", line 387, in accuracy
#     _, pred = output.topk(maxk, 1, 3, True, True)
# TypeError: topk() takes from 1 to 4 positional arguments but 5 were given
